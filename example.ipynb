# %%
import sys
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

workspace_root = Path.cwd()
if str(workspace_root) not in sys.path:
    sys.path.insert(0, str(workspace_root))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from itlubber_automl import auto_lightgbm

data_path = Path("train.xlsx")
if not data_path.exists():
    data_path = Path(r"c:/Users/18306/Documents/GitHub/auto_lightgbm/train.xlsx")

data = pd.read_excel(data_path).drop(columns=["sex"])
target = "FPD7"

print(data.shape)
print(data[target].value_counts(dropna=False).to_dict())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45200\1826643143.py in <module>
#       2 from sklearn.model_selection import train_test_split
#       3
# ----> 4 from itlubber_automl import auto_lightgbm
#       5
#       6 data_path = Path("train.xlsx")
#
# c:\Users\18306\Documents\GitHub\auto_lightgbm\itlubber_automl\__init__.py in <module>
#      10
#      11 from .utils.logger import logger
# ---> 12 from .model import auto_lightgbm, auto_logistic
#      13
#      14 __version__ = "0.1.3"
#
# c:\Users\18306\Documents\GitHub\auto_lightgbm\itlubber_automl\model.py in <module>
#      14 import pandas as pd
#      15
# ---> 16 import lightgbm as lgb
#      17 from sklearn.model_selection import train_test_split
#      18 from hscredit.core.models.classical.logistic_regression import LogisticRegression
#
# ...

# %%
dev, oot = train_test_split(
    data,
    test_size=0.25,
    random_state=42,
    stratify=data[target],
)

print(dev.shape, oot.shape)
# Out:
# (5628, 68) (1876, 68)

# %%
modeler = auto_lightgbm(
    {"dev": dev, "oot": oot},
    target=target,
    params={"num_threads": 1, "num_boost_round": 50},
    early_stopping_rounds=10,
)

model, selected_features = modeler.train(
    select_feature=True,
    select_type='feature_importance',
    single_delete=True,
    target='weight',
    imp_threhold=1e-4,
    corr_threhold=0.4,
    psi_threhold=0.1,
)
# Out:
# [ 2026-04-13 02:25:24,815 ][ INFO ][ model.py:train:78 ] 开始自动建模...
# [ 2026-04-13 02:25:24,816 ][ INFO ][ model.py:train:79 ] --------------------------------------------------
# [ 2026-04-13 02:25:25,039 ][ INFO ][ methods.py:feature_select:119 ] feature_importance阈值 0.0001
# [ 2026-04-13 02:25:25,040 ][ INFO ][ methods.py:feature_select:120 ] feature_importance删除特征个数：1, feature_importance保留特征个数：66
# [ 2026-04-13 02:25:25,040 ][ INFO ][ methods.py:feature_select:121 ] --------------------------------------------------
# [ 2026-04-13 02:25:25,326 ][ INFO ][ methods.py:feature_select:140 ] 相关性阈值: 0.4, 相关性删除特征个数: 50, 相关性保留特征个数: 16
# [ 2026-04-13 02:25:25,327 ][ INFO ][ methods.py:feature_select:141 ] --------------------------------------------------
# [ 2026-04-13 02:25:25,904 ][ INFO ][ methods.py:feature_select:152 ] PSI阈值 0.1
# [ 2026-04-13 02:25:25,905 ][ INFO ][ methods.py:feature_select:153 ] PSI删除特征个数: 0, PSI保留特征个数: 16
# ...

# %%
print(f"selected_features: {len(selected_features)}")
print(selected_features[:20])
print(type(model).__name__)
# Out:
# selected_features: 13
# ['历史夜间查询次数', '历史单月单一机构平均查询次数', '历史有贷款申请天数_平均申请次数', '历史贷款申请状态创建的最小金额', '近7天贷款申请状态创建的金额', '历史贷款申请状态被批准的最小金额', '历史贷款申请对象生产过程用品（周转材料）的最小金额', '历史贷款申请对象商业房地产的次数', '历史贷款申请用途购买的最小金额', '历史贷款申请用途其他的最小金额', '历史贷款申请用途补充流动资金的金额', '历史贷款申请拒绝平均金额_批准平均金额比', 'salary']
# Booster

# %%
# sym:auto_logistic
from itlubber_automl import auto_logistic

logistic_data = data[selected_features + [target]].copy()

logistic = auto_logistic(
    logistic_data,
    target=target,
    params={"num_threads": 1, "num_boost_round": 32},
    early_stopping_rounds=10,
    importance=1e-4,
    corr=0.5,
    psi=0.1,
    test_size=0.25,
    seed=348,
    max_rounds=32,
    mertic="ootks",
    balance_weight=0.2,
    C=1,
    class_weight=None,
    max_iter=32,
    select_type="feature_importance",
)

logistic.summary()
# Out:
# [ 2026-04-13 02:25:31,005 ][ INFO ][ model.py:train:78 ] 开始自动建模...
# [ 2026-04-13 02:25:31,006 ][ INFO ][ model.py:train:79 ] --------------------------------------------------
# [ 2026-04-13 02:25:31,066 ][ INFO ][ methods.py:feature_select:119 ] feature_importance阈值 0.0001
# [ 2026-04-13 02:25:31,067 ][ INFO ][ methods.py:feature_select:120 ] feature_importance删除特征个数：0, feature_importance保留特征个数：13
# [ 2026-04-13 02:25:31,067 ][ INFO ][ methods.py:feature_select:121 ] --------------------------------------------------
# [ 2026-04-13 02:25:31,112 ][ INFO ][ methods.py:feature_select:140 ] 相关性阈值: 0.5, 相关性删除特征个数: 0, 相关性保留特征个数: 13
# [ 2026-04-13 02:25:31,113 ][ INFO ][ methods.py:feature_select:141 ] --------------------------------------------------
# [ 2026-04-13 02:25:31,526 ][ INFO ][ methods.py:feature_select:152 ] PSI阈值 0.1
# [ 2026-04-13 02:25:31,527 ][ INFO ][ methods.py:feature_select:153 ] PSI删除特征个数: 0, PSI保留特征个数: 13
# ...
